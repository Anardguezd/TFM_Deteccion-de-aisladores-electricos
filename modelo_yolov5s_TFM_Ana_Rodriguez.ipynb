# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in C:\Users\Ana Rodriguez/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-8-23 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
import os

# %%
# %cd Desktop\MASTER IA\TFM
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM

# %%
print(len((os.listdir('02_DATASET\Anomalias'))))
# Out:
# 2305

# %%
print(len((os.listdir('02_DATASET\Sin anomalias'))))
# Out:
# 593

# %%
anomalies= os.listdir('02_DATASET\Anomalias')

# %%
no_anomalies= os.listdir('02_DATASET\Sin anomalias')

# %%
import torch
from yolov5 import utils
# %cd yolov5
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING  'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5

# %%
# !python detect.py --weights best.pt --img 640   --source .../00_DATASET\Anomalias --save-crop
# Out:
# detect: weights=['best.pt'], source=.../00_DATASET\Anomalias, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-8-30 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\00_DATASET\Anomalias\L300874-21-0241-V.JPG: 640x448 3 insulators, 125.0ms
# image 2/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\00_DATASET\Anomalias\L300874-21-0242-V.JPG: 640x448 3 insulators, 109.3ms
# ...

# %%
# !python detect.py --weights best.pt --img 640   --source .../00_DATASET\Sin_anomalias --save-crop
# Out:
# detect: weights=['best.pt'], source=.../00_DATASET\Sin_anomalias, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-8-30 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/593 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\00_DATASET\Sin_anomalias\L302115-21-0468-V.JPG: 640x448 5 insulators, 119.8ms
# image 2/593 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\00_DATASET\Sin_anomalias\L302115-21-0469-V.JPG: 640x448 5 insulators, 93.7ms
# ...

# %%
# %cd Desktop\MASTER IA\TFM\20230831\yolov5
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5

# %%
# !python val.py --weights best.pt --data insulator.yaml --img 640
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-8-30 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\labels\val...:   0%|          | 0/30 [00:00<?, ?it/s]
# ...

# %%
# !python val.py --weights best.pt --data insulator.yaml --task test
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-8-30 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5\labels\test...:   0%|          | 0/10 [00:00<?, ?it/s]C:\Users\Ana Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3176: DecompressionBombWarning: Image size (101756928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#
# ...

# %%
##TEST
# !python test.py --weights best.pt --data insulator.yaml --img 640 --iou 0.65
# Out:
# python: can't open file 'C:\\Users\\Ana Rodriguez\\Desktop\\MASTER IA\\TFM\\20230831\\yolov5\\test.py': [Errno 2] No such file or directory

# %%
# %cd Desktop\MASTER IA\TFM\20230831\yolov5\
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230831\yolov5

# %%
# %tensorboard --logdir=runs/val --host=localhost --port=6006
# Out:
#       <iframe id="tensorboard-frame-ad754e663673fcc2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ad754e663673fcc2");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
