# %%
import torch
from yolov5 import utils
# %cd yolov5
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING  'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5

# %%
# !python train.py --img 640 --batch 4 --epochs 80 --data insulator.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=insulator.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=80, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# ...

# %%
# !python val.py --weights best.pt --data insulator.yaml --img 640
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\labels\val...:   0%|          | 0/60 [00:00<?, ?it/s]
# ...

# %%
# !python val.py --weights best.pt --data insulator.yaml --task test
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\labels\test...:   0%|          | 0/10 [00:00<?, ?it/s]C:\Users\Ana Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3176: DecompressionBombWarning: Image size (101756928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=runs/val --port=6006
# Out:
#       <iframe id="tensorboard-frame-2412c385d9970d6a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2412c385d9970d6a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %cd Desktop\MASTER IA\TFM\20230918\yolov5
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5

# %%
# !python detect.py --weights best.pt --img 640   --source .../00_DATASET\Anomalias --save-crop
# Out:
# detect: weights=['best.pt'], source=.../00_DATASET\Anomalias, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Anomalias\L300874-21-0241-V.JPG: 640x448 3 insulators, 161.0ms
# image 2/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Anomalias\L300874-21-0242-V.JPG: 640x448 3 insulators, 93.7ms
# ...

# %%
# !python detect.py --weights best.pt --img 640   --source .../00_DATASET\Sin_anomalias --save-crop
# Out:
# detect: weights=['best.pt'], source=.../00_DATASET\Sin_anomalias, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/593 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Sin_anomalias\L302115-21-0468-V.JPG: 640x448 6 insulators, 109.4ms
# image 2/593 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Sin_anomalias\L302115-21-0469-V.JPG: 640x448 5 insulators, 125.0ms
# ...

# %%
###METRICAS EN TRAIN

# %%
# %cd Desktop\MASTER IA\TFM\20230918\yolov5
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5

# %%
###METRICAS EN VAL

# %%
# %cd Desktop\MASTER IA\TFM\20230918\yolov5\runs\train
# Out:
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\runs\train

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=runs/val --port=6005
# Out:
#       <iframe id="tensorboard-frame-89b46cccfe24035d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-89b46cccfe24035d");
#           const url = new URL("/", window.location);
#           const port = 6005;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from utils.plots import plot_results

# %%
plot_results('exp/results.csv')  # plot 'results.csv' as 'results.png'

# %%
# !python val.py --weights best.pt --data insulator.yaml --img 640
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\labels\val...:   0%|          | 0/60 [00:00<?, ?it/s]
# ...

# %%
###METRICAS EN TEST

# %%
# !python val.py --weights best.pt --data insulator.yaml --task test
# Out:
# val: data=insulator.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\labels\test...:   0%|          | 0/10 [00:00<?, ?it/s]C:\Users\Ana Rodriguez\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3176: DecompressionBombWarning: Image size (101756928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=runs/val --port=6005
# Out:
# Reusing TensorBoard on port 6005 (pid 19104), started 0:10:06 ago. (Use '!kill 19104' to kill it.)
#       <iframe id="tensorboard-frame-4150b886c2f39f25" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4150b886c2f39f25");
#           const url = new URL("/", window.location);
#           const port = 6005;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir={runs/val} --port=6005
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-15406c1311097a35" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-15406c1311097a35");
#           const url = new URL("/", window.location);
#           const port = 6005;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
