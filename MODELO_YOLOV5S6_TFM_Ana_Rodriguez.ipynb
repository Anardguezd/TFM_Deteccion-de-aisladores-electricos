# %%
import torch
from yolov5 import utils
# %cd yolov5
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING  'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
# C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5

# %%
# !python train.py --img 1280 --batch 4 --epochs 100 --data insulator.yaml --weights yolov5s6.pt --cache
# Out:
# train: weights=yolov5s6.pt, cfg=, data=insulator.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#    6262c7f..bb9706e  master     -> origin/master
# github:  YOLOv5 is out of date by 2 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# ...

# %%
# !python detect.py --weights best_v5s6.pt --img 1280   --source .../00_DATASET\Anomalias --save-crop --save-txt
# Out:
# detect: weights=['best_v5s6.pt'], source=.../00_DATASET\Anomalias, data=data\coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 206 layers, 12308200 parameters, 0 gradients, 16.1 GFLOPs
# image 1/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Anomalias\L300874-21-0241-V.JPG: 1280x896 3 insulators, 385.5ms
# image 2/2304 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Anomalias\L300874-21-0242-V.JPG: 1280x896 3 insulators, 359.3ms
# ...

# %%
# !python detect.py --weights best_v5s6.pt --img 1280   --source .../00_DATASET\Sin_anomalias --save-crop --save-txt
# Out:
# detect: weights=['best_v5s6.pt'], source=.../00_DATASET\Sin_anomalias, data=data\coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 206 layers, 12308200 parameters, 0 gradients, 16.1 GFLOPs
# image 1/593 C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\00_DATASET\Sin_anomalias\L302115-21-0468-V.JPG: 1280x896 4 insulators, 421.8ms
# ...

# %%
# !python val.py --weights best_v5s6.pt --data insulator.yaml --img 1280
# Out:
# val: data=insulator.yaml, weights=['best_v5s6.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Ana': Invalid argument
# YOLOv5  2023-9-18 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 206 layers, 12308200 parameters, 0 gradients, 16.1 GFLOPs
#
# val: Scanning C:\Users\Ana Rodriguez\Desktop\MASTER IA\TFM\20230918\yolov5\labels\val...:   0%|          | 0/60 [00:00<?, ?it/s]
# ...

# %%
###MÉTRICAS
# %load_ext tensorboard
# %tensorboard --logdir=runs/train
# Out:
#       <iframe id="tensorboard-frame-ac5688af994da4ff" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ac5688af994da4ff");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs/val
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-306f49edfefbf75" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-306f49edfefbf75");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#MÉTRICAS EVLUACION EN TEST- mAP

# %%
import json

# %%
with open('labels_true\VI0072-21-00572-V.txt', 'r') as archivo: 
    y_true = archivo.read()
with open('labels\VI0072-21-00572-V.txt', 'r') as archivo: 
    y_pred = archivo.read()

# %%
#Transformar de txt a json.

# %%
lineas = y_true.split('\n')
for linea in lineas:
    clave, valor = linea.split(':')
    datos[clave.strip()] = float(valor.strip())

# %%
with open('archivo.json', 'w') as archivo_json:
    json.dump(datos, archivo_json)

# %%
import torch
from torchvision.models.detection import yolo

# Cargar el modelo entrenado
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Obtener las etiquetas de objetos de la imagen y guardarlas
y_true=
y_pred=

# Calcular el Average Precision (AP) para cada clase de objeto
ap_per_class, _ = yolo.metrics.ap(y_pred, y_true)

# Calcular el área bajo la curva Precision-Recall (APR) para cada clase de objeto
apr_per_class = [torch.trapz(ap_class.values()) for ap_class in ap_per_class]

# Calcular el mAP promediando los APR de todas las clases de objetos
mAP = torch.mean(torch.tensor(apr_per_class))

print(f'mAP: {mAP.item()}')
